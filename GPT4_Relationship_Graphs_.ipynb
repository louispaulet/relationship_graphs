# %% [markdown]
# # 🌟 Network Graphs: Unveiling Relationships in The Office! 🌟
#
# 👋 Welcome to this exciting Google Colab notebook! In the following cells, we will be exploring an interesting and fun approach to analyze the relationships between the beloved characters of the famous TV show, "The Office". 📺
#
# Television series often revolve around intricate character relationships, and "The Office" is no exception. Understanding these relationships can provide insights into the dynamics of the show, and in a broader perspective, it can offer a visual way to analyze and understand complex relational data. 📊
#
# Using Python's `networkx` and `matplotlib` libraries, we will build an interactive graph 📈 that beautifully represents the connections between characters. This visualization will help us comprehend the various relationships that exist, ranging from professional connections 👥 to romantic entanglements 💕.
#
# We will be defining a general function to parse JSON data and visualize it as a graph. Once we create this function, it can be used with any similar data set to generate comparable graphs. 🔄
#
# To make it even more interesting, we will also be saving the generated graph images 🖼️ in a directory for further use.
#
# So let's dive in and explore the complex world of relationships in "The Office"! Buckle up for a great ride through the corridors of Dunder Mifflin Paper Company Inc. 🏢🎢!

# %% [markdown]
# # V1

# %%
import json
import networkx as nx
import matplotlib.pyplot as plt

# JSON data as a large string
json_data = '''
{
  "nodes": [
    { "id": "michael", "label": "Michael Scott" },
    { "id": "jim", "label": "Jim Halpert" },
    { "id": "pam", "label": "Pam Beesly" },
    { "id": "dwight", "label": "Dwight Schrute" },
    { "id": "angela", "label": "Angela Martin" },
    { "id": "oscar", "label": "Oscar Martinez" },
    { "id": "kevin", "label": "Kevin Malone" },
    { "id": "stanley", "label": "Stanley Hudson" },
    { "id": "phyllis", "label": "Phyllis Vance" },
    { "id": "meredith", "label": "Meredith Palmer" }
  ],
  "links": [
    { "source": "michael", "target": "jim", "label": "boss" },
    { "source": "michael", "target": "pam", "label": "boss" },
    { "source": "michael", "target": "dwight", "label": "boss" },
    { "source": "dwight", "target": "jim", "label": "colleague" },
    { "source": "dwight", "target": "angela", "label": "romantic partner" },
    { "source": "angela", "target": "oscar", "label": "colleague" },
    { "source": "kevin", "target": "oscar", "label": "colleague" },
    { "source": "stanley", "target": "phyllis", "label": "colleague" },
    { "source": "meredith", "target": "kevin", "label": "colleague" }
  ]
}
'''

# Load JSON data from the string
data = json.loads(json_data)

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
for node in data['nodes']:
    G.add_node(node['id'], label=node['label'])

# Add edges to the graph
for link in data['links']:
    G.add_edge(link['source'], link['target'], label=link['label'])

# Generate a layout for the graph
pos = nx.spring_layout(G)

# Draw nodes with labels
labels = nx.get_node_attributes(G, 'label')
nx.draw_networkx_nodes(G, pos, node_size=200, alpha=0.8)
nx.draw_networkx_labels(G, pos, labels, font_size=16)

# Draw edges with labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=14)

# Display the graph
plt.axis('off')
plt.show()

# %%
import json
import networkx as nx
import matplotlib.pyplot as plt

# JSON data as a large string
json_data = '''
{
  "nodes": [
    { "id": "michael", "label": "Michael Scott" },
    { "id": "jim", "label": "Jim Halpert" },
    { "id": "pam", "label": "Pam Beesly" },
    { "id": "dwight", "label": "Dwight Schrute" },
    { "id": "angela", "label": "Angela Martin" },
    { "id": "oscar", "label": "Oscar Martinez" },
    { "id": "kevin", "label": "Kevin Malone" },
    { "id": "stanley", "label": "Stanley Hudson" },
    { "id": "phyllis", "label": "Phyllis Vance" },
    { "id": "meredith", "label": "Meredith Palmer" }
  ],
  "links": [
    { "source": "michael", "target": "jim", "label": "boss" },
    { "source": "michael", "target": "pam", "label": "boss" },
    { "source": "michael", "target": "dwight", "label": "boss" },
    { "source": "dwight", "target": "jim", "label": "colleague" },
    { "source": "dwight", "target": "angela", "label": "romantic partner" },
    { "source": "angela", "target": "oscar", "label": "colleague" },
    { "source": "kevin", "target": "oscar", "label": "colleague" },
    { "source": "stanley", "target": "phyllis", "label": "colleague" },
    { "source": "meredith", "target": "kevin", "label": "colleague" }
  ]
}
'''

# Load JSON data from the string
data = json.loads(json_data)

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
for node in data['nodes']:
    G.add_node(node['id'], label=node['label'])

# Add edges to the graph
for link in data['links']:
    G.add_edge(link['source'], link['target'], label=link['label'])

# Generate a layout for the graph
pos = nx.spring_layout(G)

# Increase the figure size
plt.figure(figsize=(15, 15))

# Draw nodes with labels
labels = nx.get_node_attributes(G, 'label')
nx.draw_networkx_nodes(G, pos, node_size=2000, alpha=0.8)
nx.draw_networkx_labels(G, pos, labels, font_size=10)

# Draw edges with labels and increase edge length
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, edge_color='black')
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=8, label_pos=0.5, rotate=False)

# Display the graph
plt.axis('off')
plt.show()

# %%
import json
import networkx as nx
import matplotlib.pyplot as plt

# JSON data as a large string
json_data="""

{
  "nodes": [
    { "id": "michael", "label": "Michael Scott" },
    { "id": "jim", "label": "Jim Halpert" },
    { "id": "pam", "label": "Pam Beesly" },
    { "id": "dwight", "label": "Dwight Schrute" },
    { "id": "angela", "label": "Angela Martin" },
    { "id": "oscar", "label": "Oscar Martinez" },
    { "id": "kevin", "label": "Kevin Malone" },
    { "id": "stanley", "label": "Stanley Hudson" },
    { "id": "phyllis", "label": "Phyllis Vance" },
    { "id": "meredith", "label": "Meredith Palmer" },
    { "id": "toby", "label": "Toby Flenderson" },
    { "id": "ryan", "label": "Ryan Howard" },
    { "id": "kelly", "label": "Kelly Kapoor" },
    { "id": "creed", "label": "Creed Bratton" },
    { "id": "jan", "label": "Jan Levinson" },
    { "id": "andy", "label": "Andy Bernard" },
    { "id": "erin", "label": "Erin Hannon" },
    { "id": "darryl", "label": "Darryl Philbin" }
  ],
  "links": [
    { "source": "michael", "target": "jim", "label": "boss" },
    { "source": "michael", "target": "pam", "label": "boss" },
    { "source": "michael", "target": "dwight", "label": "boss" },
    { "source": "michael", "target": "ryan", "label": "boss" },
    { "source": "michael", "target": "jan", "label": "romantic partner" },
    { "source": "dwight", "target": "jim", "label": "colleague" },
    { "source": "dwight", "target": "angela", "label": "romantic partner" },
    { "source": "dwight", "target": "andy", "label": "colleague" },
    { "source": "angela", "target": "oscar", "label": "colleague" },
    { "source": "angela", "target": "andy", "label": "romantic partner" },
    { "source": "kevin", "target": "oscar", "label": "colleague" },
    { "source": "stanley", "target": "phyllis", "label": "colleague" },
    { "source": "meredith", "target": "kevin", "label": "colleague" },
    { "source": "toby", "target": "michael", "label": "human resources" },
    { "source": "ryan", "target": "kelly", "label": "romantic partner" },
    { "source": "kelly", "target": "ryan", "label": "romantic partner" },
    { "source": "creed", "target": "dwight", "label": "colleague" },
    { "source": "creed", "target": "meredith", "label": "colleague" },
    { "source": "andy", "target": "erin", "label": "romantic partner" },
    { "source": "erin", "target": "pete", "label": "romantic partner" },
    { "source": "jim", "target": "pam", "label": "romantic partner" },
    { "source": "darryl", "target": "andy", "label": "colleague" },
    { "source": "darryl", "target": "jim", "label": "colleague" },
    { "source": "darryl", "target": "michael", "label": "colleague" }
  ]
}


"""



# Load JSON data from the string
data = json.loads(json_data)

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
for node in data['nodes']:
    G.add_node(node['id'], label=node['label'])

# Add edges to the graph
for link in data['links']:
    G.add_edge(link['source'], link['target'], label=link['label'])

# Generate a layout for the graph
pos = nx.spring_layout(G)

# Increase the figure size
plt.figure(figsize=(15, 15))

# Draw nodes with labels
labels = nx.get_node_attributes(G, 'label')
nx.draw_networkx_nodes(G, pos, node_size=2000, alpha=0.8)
nx.draw_networkx_labels(G, pos, labels, font_size=10)

# Draw edges with labels and increase edge length
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, edge_color='black')
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=8, label_pos=0.5, rotate=False)

# Display the graph
plt.axis('off')
plt.show()

# %% [markdown]
# # General function here

# %% [markdown]
# ## create save directory (change if needed)

# %%
# !mkdir -p /content/drive/MyDrive/AI/graphs/graph_images

# %% [markdown]
# ## define general function (change directory if needed here also)

# %%
import json
import networkx as nx
import matplotlib.pyplot as plt
import time
from datetime import datetime


save_path = "/content/drive/MyDrive/AI/graphs/graph_images/"


def display_json_data(json_data, sizeX=15, sizeY=15):
    # Load JSON data from the string
    data = json.loads(json_data)

    # Create an empty graph
    G = nx.Graph()

    # Add nodes to the graph
    for node in data['nodes']:
        G.add_node(node['id'], label=node['label'])

    # Add edges to the graph
    for link in data['links']:
        G.add_edge(link['source'], link['target'], label=link['label'])

    # Generate a layout for the graph
    pos = nx.spring_layout(G)

    # Increase the figure size
    plt.figure(figsize=(sizeX, sizeY))

    # Draw nodes with labels
    labels = nx.get_node_attributes(G, 'label')
    nx.draw_networkx_nodes(G, pos, node_size=2000, alpha=0.8)
    nx.draw_networkx_labels(G, pos, labels, font_size=10)

    # Draw edges with labels and increase edge length
    edge_labels = nx.get_edge_attributes(G, 'label')
    nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, edge_color='black')
    nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=8, label_pos=0.5, rotate=False)

    # Save the graph image with a filename prefixed with a timestamp (including milliseconds)
    # timestamp = time.strftime("%Y%m%d%H%M%S%f")
    timestamp = datetime.now().strftime("%H:%M:%S.%f")
    filename = f"{save_path}graph_{timestamp}.png"
    plt.savefig(filename)

    # Display the graph
    plt.axis('off')
    plt.show()

    # Close the plot to release memory
    plt.close()

# %% [markdown]
# # Movies and TV shows

# %% [markdown]
# ## The Office exhaustive character relationships

# %%
json_data="""

{
  "nodes": [
    { "id": "michael", "label": "Michael Scott" },
    { "id": "jim", "label": "Jim Halpert" },
    { "id": "pam", "label": "Pam Beesly" },
    { "id": "dwight", "label": "Dwight Schrute" },
    { "id": "angela", "label": "Angela Martin" },
    { "id": "oscar", "label": "Oscar Martinez" },
    { "id": "kevin", "label": "Kevin Malone" },
    { "id": "stanley", "label": "Stanley Hudson" },
    { "id": "phyllis", "label": "Phyllis Vance" },
    { "id": "meredith", "label": "Meredith Palmer" },
    { "id": "toby", "label": "Toby Flenderson" },
    { "id": "ryan", "label": "Ryan Howard" },
    { "id": "kelly", "label": "Kelly Kapoor" },
    { "id": "creed", "label": "Creed Bratton" },
    { "id": "jan", "label": "Jan Levinson" },
    { "id": "andy", "label": "Andy Bernard" },
    { "id": "erin", "label": "Erin Hannon" },
    { "id": "darryl", "label": "Darryl Philbin" }
  ],
  "links": [
    { "source": "michael", "target": "jim", "label": "boss" },
    { "source": "michael", "target": "pam", "label": "boss" },
    { "source": "michael", "target": "dwight", "label": "boss" },
    { "source": "michael", "target": "ryan", "label": "boss" },
    { "source": "michael", "target": "jan", "label": "romantic partner" },
    { "source": "dwight", "target": "jim", "label": "colleague" },
    { "source": "dwight", "target": "angela", "label": "romantic partner" },
    { "source": "dwight", "target": "andy", "label": "colleague" },
    { "source": "angela", "target": "oscar", "label": "colleague" },
    { "source": "angela", "target": "andy", "label": "romantic partner" },
    { "source": "kevin", "target": "oscar", "label": "colleague" },
    { "source": "stanley", "target": "phyllis", "label": "colleague" },
    { "source": "meredith", "target": "kevin", "label": "colleague" },
    { "source": "toby", "target": "michael", "label": "human resources" },
    { "source": "ryan", "target": "kelly", "label": "romantic partner" },
    { "source": "kelly", "target": "ryan", "label": "romantic partner" },
    { "source": "creed", "target": "dwight", "label": "colleague" },
    { "source": "creed", "target": "meredith", "label": "colleague" },
    { "source": "andy", "target": "erin", "label": "romantic partner" },
    { "source": "erin", "target": "pete", "label": "romantic partner" },
    { "source": "jim", "target": "pam", "label": "romantic partner" },
    { "source": "darryl", "target": "andy", "label": "colleague" },
    { "source": "darryl", "target": "jim", "label": "colleague" },
    { "source": "darryl", "target": "michael", "label": "colleague" }
  ]
}


"""

# %%
display_json_data(json_data)

# %% [markdown]
# ## Parcs and Recs

# %%
json_data="""
{
  "nodes": [
    { "id": "leslie", "label": "Leslie Knope" },
    { "id": "ann", "label": "Ann Perkins" },
    { "id": "ron", "label": "Ron Swanson" },
    { "id": "tom", "label": "Tom Haverford" },
    { "id": "april", "label": "April Ludgate" },
    { "id": "andy", "label": "Andy Dwyer" },
    { "id": "ben", "label": "Ben Wyatt" },
    { "id": "jerry", "label": "Jerry Gergich" },
    { "id": "donna", "label": "Donna Meagle" },
    { "id": "chris", "label": "Chris Traeger" },
    { "id": "mark", "label": "Mark Brendanawicz" }
  ],
  "links": [
    { "source": "leslie", "target": "ann", "label": "best friend" },
    { "source": "leslie", "target": "ron", "label": "boss" },
    { "source": "leslie", "target": "tom", "label": "subordinate" },
    { "source": "leslie", "target": "april", "label": "subordinate" },
    { "source": "leslie", "target": "andy", "label": "friend" },
    { "source": "leslie", "target": "ben", "label": "romantic partner" },
    { "source": "leslie", "target": "jerry", "label": "subordinate" },
    { "source": "leslie", "target": "donna", "label": "subordinate" },
    { "source": "leslie", "target": "chris", "label": "boss" },
    { "source": "leslie", "target": "mark", "label": "colleague" },
    { "source": "ann", "target": "leslie", "label": "best friend" },
    { "source": "ann", "target": "chris", "label": "romantic partner" },
    { "source": "ron", "target": "leslie", "label": "subordinate" },
    { "source": "tom", "target": "leslie", "label": "boss" },
    { "source": "april", "target": "leslie", "label": "boss" },
    { "source": "april", "target": "andy", "label": "romantic partner" },
    { "source": "andy", "target": "april", "label": "romantic partner" },
    { "source": "ben", "target": "leslie", "label": "romantic partner" },
    { "source": "jerry", "target": "leslie", "label": "boss" },
    { "source": "donna", "target": "leslie", "label": "boss" },
    { "source": "chris", "target": "leslie", "label": "subordinate" },
    { "source": "mark", "target": "leslie", "label": "colleague" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)

# %% [markdown]
# ## Matrix main characters relationships

# %%
json_data="""
 {
  "nodes": [
    { "id": "neo", "label": "Neo" },
    { "id": "trinity", "label": "Trinity" },
    { "id": "morpheus", "label": "Morpheus" },
    { "id": "agent_smith", "label": "Agent Smith" },
    { "id": "oracle", "label": "The Oracle" }
  ],
  "links": [
    { "source": "neo", "target": "trinity", "label": "romantic partner" },
    { "source": "neo", "target": "morpheus", "label": "mentor" },
    { "source": "neo", "target": "agent_smith", "label": "enemy" },
    { "source": "trinity", "target": "morpheus", "label": "ally" },
    { "source": "trinity", "target": "agent_smith", "label": "enemy" },
    { "source": "morpheus", "target": "agent_smith", "label": "enemy" },
    { "source": "morpheus", "target": "oracle", "label": "ally" },
    { "source": "neo", "target": "oracle", "label": "ally" },
    { "source": "trinity", "target": "oracle", "label": "ally" }
  ]
}
"""

# %%
display_json_data(json_data, 5, 5)

# %% [markdown]
# ## LOTR main characters relationships

# %%
json_data="""
{
  "nodes": [
    { "id": "frodo", "label": "Frodo Baggins" },
    { "id": "sam", "label": "Samwise Gamgee" },
    { "id": "gandalf", "label": "Gandalf" },
    { "id": "aragorn", "label": "Aragorn" },
    { "id": "legolas", "label": "Legolas" },
    { "id": "gimli", "label": "Gimli" },
    { "id": "pippin", "label": "Peregrin Took" },
    { "id": "merry", "label": "Meriadoc Brandybuck" },
    { "id": "boromir", "label": "Boromir" },
    { "id": "sauron", "label": "Sauron" },
    { "id": "saruman", "label": "Saruman" },
    { "id": "gollum", "label": "Gollum" },
    { "id": "bilbo", "label": "Bilbo Baggins" },
    { "id": "elrond", "label": "Elrond" },
    { "id": "galadriel", "label": "Galadriel" },
     { "id": "arwen", "label": "Arwen" },
    { "id": "théoden", "label": "Théoden" },
    { "id": "éowyn", "label": "Éowyn" },
    { "id": "faramir", "label": "Faramir" },
    { "id": "treebeard", "label": "Treebeard" },
    { "id": "gríma", "label": "Gríma Wormtongue" },
    { "id": "denethor", "label": "Denethor" }
  ],
  "links": [
    { "source": "frodo", "target": "sam", "label": "friend" },
    { "source": "frodo", "target": "gandalf", "label": "friend" },
    { "source": "frodo", "target": "aragorn", "label": "friend" },
    { "source": "frodo", "target": "gollum", "label": "enemy" },
    { "source": "gandalf", "target": "aragorn", "label": "friend" },
    { "source": "gandalf", "target": "saruman", "label": "enemy" },
    { "source": "aragorn", "target": "legolas", "label": "friend" },
    { "source": "aragorn", "target": "gimli", "label": "friend" },
    { "source": "legolas", "target": "gimli", "label": "friend" },
    { "source": "pippin", "target": "merry", "label": "friend" },
    { "source": "boromir", "target": "aragorn", "label": "friend" },
    { "source": "sauron", "target": "saruman", "label": "ally" },
    { "source": "bilbo", "target": "frodo", "label": "relative" },
    { "source": "elrond", "target": "aragorn", "label": "ally" },
    { "source": "galadriel", "target": "gandalf", "label": "ally" },
    { "source": "arwen", "target": "aragorn", "label": "romantic partner" },
    { "source": "arwen", "target": "elrond", "label": "daughter" },
    { "source": "théoden", "target": "éowyn", "label": "niece" },
    { "source": "théoden", "target": "gríma", "label": "enemy" },
    { "source": "éowyn", "target": "aragorn", "label": "ally" },
    { "source": "éowyn", "target": "faramir", "label": "romantic partner" },
    { "source": "faramir", "target": "boromir", "label": "brother" },
    { "source": "faramir", "target": "denethor", "label": "son" },
    { "source": "treebeard", "target": "merry", "label": "ally" },
    { "source": "treebeard", "target": "pippin", "label": "ally" }
  ]
}
"""

# %%
display_json_data(json_data, 20, 20)

# %% [markdown]
# ## BTTF

# %%
json_data="""
{
  "links": [
    { "source": "marty", "target": "doc", "label": "friend" },
    { "source": "marty", "target": "george", "label": "son" },
    { "source": "marty", "target": "lorraine", "label": "son" },
    { "source": "marty", "target": "jennifer", "label": "romantic partner" },
    { "source": "marty", "target": "biff", "label": "enemy" },
    { "source": "doc", "target": "einstein", "label": "pet" },
    { "source": "doc", "target": "clara", "label": "romantic partner" },
    { "source": "george", "target": "lorraine", "label": "husband" },
    { "source": "george", "target": "biff", "label": "enemy" },
    { "source": "lorraine", "target": "biff", "label": "unwanted suitor" },
    { "source": "biff", "target": "griff", "label": "grandfather" },
    { "source": "biff", "target": "buford", "label": "ancestor" }
  ],
  "nodes": [
    { "id": "marty", "label": "Marty McFly" },
    { "id": "doc", "label": "Doc Brown" },
    { "id": "george", "label": "George McFly" },
    { "id": "lorraine", "label": "Lorraine Baines" },
    { "id": "jennifer", "label": "Jennifer Parker" },
    { "id": "biff", "label": "Biff Tannen" },
    { "id": "einstein", "label": "Einstein" },
    { "id": "clara", "label": "Clara Clayton" },
    { "id": "griff", "label": "Griff Tannen" },
    { "id": "buford", "label": "Buford Tannen" }
  ]
}
"""

# %%
display_json_data(json_data, 12, 12)

# %% [markdown]
# ## Harry Potter

# %%
json_data="""
{
  "nodes": [
    { "id": "harry", "label": "Harry Potter" },
    { "id": "ron", "label": "Ron Weasley" },
    { "id": "hermione", "label": "Hermione Granger" },
    { "id": "dumbledore", "label": "Albus Dumbledore" },
    { "id": "voldemort", "label": "Lord Voldemort" },
    { "id": "snape", "label": "Severus Snape" },
    { "id": "malfoy", "label": "Draco Malfoy" },
    { "id": "sirius", "label": "Sirius Black" },
    { "id": "hagrid", "label": "Rubeus Hagrid" },
    { "id": "neville", "label": "Neville Longbottom" },
    { "id": "ginny", "label": "Ginny Weasley" },
    { "id": "fred", "label": "Fred Weasley" },
    { "id": "george", "label": "George Weasley" },
    { "id": "luna", "label": "Luna Lovegood" },
    { "id": "mcgonagall", "label": "Minerva McGonagall" },
    { "id": "lupin", "label": "Remus Lupin" },
    { "id": "wormtail", "label": "Peter Pettigrew" },
    { "id": "dobby", "label": "Dobby" },
    { "id": "hedwig", "label": "Hedwig" },
    { "id": "dudley", "label": "Dudley Dursley" },
    { "id": "bellatrix", "label": "Bellatrix Lestrange" },
    { "id": "lily", "label": "Lily Potter" },
    { "id": "tonks", "label": "Nymphadora Tonks" },
    { "id": "crabbe", "label": "Vincent Crabbe" },
    { "id": "goyle", "label": "Gregory Goyle" }
  ],
  "links": [
    { "source": "harry", "target": "ron", "label": "friend" },
    { "source": "harry", "target": "hermione", "label": "friend" },
    { "source": "harry", "target": "dumbledore", "label": "mentor" },
    { "source": "harry", "target": "voldemort", "label": "enemy" },
    { "source": "harry", "target": "snape", "label": "complicated" },
    { "source": "harry", "target": "malfoy", "label": "rival" },
    { "source": "harry", "target": "sirius", "label": "godfather" },
    { "source": "harry", "target": "hagrid", "label": "friend" },
    { "source": "harry", "target": "neville", "label": "friend" },
    { "source": "harry", "target": "ginny", "label": "romantic partner" },
    { "source": "harry", "target": "dobby", "label": "friend" },
    { "source": "harry", "target": "hedwig", "label": "pet" },
    { "source": "harry", "target": "dudley", "label": "relative" },
    { "source": "ron", "target": "hermione", "label": "romantic partner" },
    { "source": "ron", "target": "fred", "label": "brother" },
    { "source": "ron", "target": "george", "label": "brother" },
    { "source": "ron", "target": "ginny", "label": "sister" },
    { "source": "hermione", "target": "luna", "label": "friend" },
    { "source": "hermione", "target": "mcgonagall", "label": "mentor" },
    { "source": "dumbledore", "target": "mcgonagall", "label": "colleague" },
    { "source": "dumbledore", "target": "snape", "label": "colleague" },
    { "source": "voldemort", "target": "snape", "label": "subordinate" },
    { "source": "voldemort", "target": "malfoy", "label": "subordinate" },
    { "source": "voldemort", "target": "bellatrix", "label": "subordinate" },
    { "source": "sirius", "target": "lupin", "label": "friend" },
    { "source": "sirius", "target": "wormtail", "label": "enemy" },
    { "source": "lupin", "target": "tonks", "label": "romantic partner" },
    { "source": "snape", "target": "lily", "label": "unrequited love" },
    { "source": "malfoy", "target": "crabbe", "label": "friend" },
    { "source": "malfoy", "target": "goyle", "label": "friend" },
    { "source": "fred", "target": "george", "label": "twin brother" },
    { "source": "neville", "target": "luna", "label": "friend" },
    { "source": "neville", "target": "ginny", "label": "friend" },
    { "source": "ginny", "target": "hermione", "label": "friend" },
    { "source": "ginny", "target": "luna", "label": "friend" },
    { "source": "luna", "target": "hermione", "label": "friend" },
    { "source": "mcgonagall", "target": "dumbledore", "label": "colleague" },
    { "source": "mcgonagall", "target": "snape", "label": "colleague" },
    { "source": "dobby", "target": "malfoy", "label": "former master" },
    { "source": "snape", "target": "malfoy", "label": "mentor" },
    { "source": "snape", "target": "lily", "label": "unrequited love" },
    { "source": "wormtail", "target": "voldemort", "label": "subordinate" },
    { "source": "sirius", "target": "harry", "label": "godson" },
    { "source": "bellatrix", "target": "voldemort", "label": "loyalist" },
    { "source": "bellatrix", "target": "harry", "label": "enemy" }
  ]
}
"""

# %%
display_json_data(json_data, 20, 20)

# %% [markdown]
# ## Futurama

# %%
json_data = """
{
  "nodes": [
    { "id": "fry", "label": "Fry" },
    { "id": "bender", "label": "Bender" },
    { "id": "leela", "label": "Leela" },
    { "id": "professor", "label": "Professor Farnsworth" },
    { "id": "amy", "label": "Amy Wong" },
    { "id": "hermes", "label": "Hermes Conrad" },
    { "id": "zoidberg", "label": "Dr. Zoidberg" }
  ],
  "links": [
    { "source": "fry", "target": "bender", "label": "friend" },
    { "source": "fry", "target": "leela", "label": "colleague" },
    { "source": "fry", "target": "professor", "label": "nephew" },
    { "source": "fry", "target": "amy", "label": "colleague" },
    { "source": "fry", "target": "hermes", "label": "colleague" },
    { "source": "fry", "target": "zoidberg", "label": "colleague" },
    { "source": "bender", "target": "leela", "label": "colleague" },
    { "source": "bender", "target": "professor", "label": "employee" },
    { "source": "bender", "target": "amy", "label": "colleague" },
    { "source": "bender", "target": "hermes", "label": "colleague" },
    { "source": "bender", "target": "zoidberg", "label": "colleague" },
    { "source": "leela", "target": "professor", "label": "employee" },
    { "source": "leela", "target": "amy", "label": "colleague" },
    { "source": "leela", "target": "hermes", "label": "colleague" },
    { "source": "leela", "target": "zoidberg", "label": "colleague" },
    { "source": "professor", "target": "amy", "label": "employee" },
    { "source": "professor", "target": "hermes", "label": "employee" },
    { "source": "professor", "target": "zoidberg", "label": "employee" },
    { "source": "amy", "target": "hermes", "label": "colleague" },
    { "source": "amy", "target": "zoidberg", "label": "colleague" },
    { "source": "hermes", "target": "zoidberg", "label": "colleague" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)

# %% [markdown]
# ## Shrek

# %%
json_data="""
 {
  "nodes": [
    { "id": "shrek", "label": "Shrek" },
    { "id": "donkey", "label": "Donkey" },
    { "id": "fiona", "label": "Princess Fiona" },
    { "id": "farquaad", "label": "Lord Farquaad" },
    { "id": "dragon", "label": "Dragon" }
  ],
  "links": [
    { "source": "shrek", "target": "donkey", "label": "friend" },
    { "source": "shrek", "target": "fiona", "label": "romantic partner" },
    { "source": "shrek", "target": "farquaad", "label": "enemy" },
    { "source": "donkey", "target": "dragon", "label": "romantic partner" },
    { "source": "donkey", "target": "fiona", "label": "friend" },
    { "source": "fiona", "target": "farquaad", "label": "forced betrothed" },
    { "source": "fiona", "target": "dragon", "label": "captor" },
    { "source": "farquaad", "target": "fiona", "label": "forced betrothed" },
    { "source": "farquaad", "target": "shrek", "label": "enemy" }
  ]
}
"""

# %%
display_json_data(json_data, 5, 5)

# %% [markdown]
# ## Airplane!

# %%
json_data="""
{
  "nodes": [
    { "id": "ted", "label": "Ted Striker" },
    { "id": "elaine", "label": "Elaine Dickinson" },
    { "id": "rumack", "label": "Dr. Rumack" },
    { "id": "roger", "label": "Roger Murdock" },
    { "id": "oever", "label": "Captain Clarence Oveur" },
    { "id": "mccroskey", "label": "Steve McCroskey" }
  ],
  "links": [
    { "source": "ted", "target": "elaine", "label": "romantic interest" },
    { "source": "ted", "target": "rumack", "label": "acquaintance" },
    { "source": "ted", "target": "roger", "label": "acquaintance" },
    { "source": "ted", "target": "oever", "label": "acquaintance" },
    { "source": "ted", "target": "mccroskey", "label": "acquaintance" },
    { "source": "elaine", "target": "rumack", "label": "colleague" },
    { "source": "elaine", "target": "roger", "label": "colleague" },
    { "source": "elaine", "target": "oever", "label": "colleague" },
    { "source": "rumack", "target": "roger", "label": "colleague" },
    { "source": "rumack", "target": "oever", "label": "colleague" },
    { "source": "rumack", "target": "mccroskey", "label": "colleague" },
    { "source": "roger", "target": "oever", "label": "colleague" },
    { "source": "roger", "target": "mccroskey", "label": "colleague" },
    { "source": "oever", "target": "mccroskey", "label": "colleague" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)

# %% [markdown]
# # Real world

# %% [markdown]
# ## Donald Trump

# %%
json_data = """
{
  "nodes": [
    { "id": "donald", "label": "Donald Trump" },
    { "id": "ivana", "label": "Ivana Trump" },
    { "id": "marla", "label": "Marla Maples" },
    { "id": "melania", "label": "Melania Trump" },
    { "id": "don_jr", "label": "Donald Trump Jr." },
    { "id": "ivanka", "label": "Ivanka Trump" },
    { "id": "eric", "label": "Eric Trump" },
    { "id": "tiffany", "label": "Tiffany Trump" },
    { "id": "barron", "label": "Barron Trump" }
  ],
  "links": [
    { "source": "donald", "target": "ivana", "label": "ex-spouse" },
    { "source": "donald", "target": "marla", "label": "ex-spouse" },
    { "source": "donald", "target": "melania", "label": "spouse" },
    { "source": "donald", "target": "don_jr", "label": "son" },
    { "source": "donald", "target": "ivanka", "label": "daughter" },
    { "source": "donald", "target": "eric", "label": "son" },
    { "source": "donald", "target": "tiffany", "label": "daughter" },
    { "source": "donald", "target": "barron", "label": "son" },
    { "source": "ivana", "target": "don_jr", "label": "son" },
    { "source": "ivana", "target": "ivanka", "label": "daughter" },
    { "source": "ivana", "target": "eric", "label": "son" },
    { "source": "marla", "target": "tiffany", "label": "daughter" },
    { "source": "melania", "target": "barron", "label": "son" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)

# %% [markdown]
# ## François Hollande

# %%
json_data="""
{
  "links": [
    { "source": "francois", "target": "sego", "label": "ex-partner" },
    { "source": "francois", "target": "valerie", "label": "ex-partner" },
    { "source": "francois", "target": "julie", "label": "partner" },
    { "source": "francois", "target": "thomas", "label": "son" },
    { "source": "francois", "target": "clement", "label": "son" },
    { "source": "francois", "target": "julien", "label": "son" },
    { "source": "francois", "target": "flora", "label": "daughter" },
    { "source": "sego", "target": "thomas", "label": "son" },
    { "source": "sego", "target": "clement", "label": "son" },
    { "source": "sego", "target": "julien", "label": "son" },
    { "source": "sego", "target": "flora", "label": "daughter" }
  ],
  "nodes": [
    { "id": "francois", "label": "François Hollande" },
    { "id": "sego", "label": "Ségolène Royal" },
    { "id": "valerie", "label": "Valérie Trierweiler" },
    { "id": "julie", "label": "Julie Gayet" },
    { "id": "thomas", "label": "Thomas Hollande" },
    { "id": "clement", "label": "Clément Hollande" },
    { "id": "julien", "label": "Julien Hollande" },
    { "id": "flora", "label": "Flora Hollande" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)

# %% [markdown]
# ## Nicolas Sarkozy

# %%
json_data = """
{
  "links": [
    { "source": "nicolas", "target": "cecilia", "label": "ex-spouse" },
    { "source": "nicolas", "target": "carla", "label": "spouse" },
    { "source": "nicolas", "target": "pierre", "label": "son" },
    { "source": "nicolas", "target": "jean", "label": "son" },
    { "source": "nicolas", "target": "louis", "label": "son" },
    { "source": "nicolas", "target": "giulia", "label": "daughter" },
    { "source": "cecilia", "target": "pierre", "label": "son" },
    { "source": "cecilia", "target": "jean", "label": "son" },
    { "source": "carla", "target": "giulia", "label": "daughter" }
  ],
  "nodes": [
    { "id": "nicolas", "label": "Nicolas Sarkozy" },
    { "id": "cecilia", "label": "Cecilia Sarkozy" },
    { "id": "carla", "label": "Carla Bruni" },
    { "id": "pierre", "label": "Pierre Sarkozy" },
    { "id": "jean", "label": "Jean Sarkozy" },
    { "id": "louis", "label": "Louis Sarkozy" },
    { "id": "giulia", "label": "Giulia Sarkozy" }
  ]
}
"""

# %%
display_json_data(json_data, 8, 8)
